# %%
import numpy as np
from matplotlib.colors import ListedColormap
from sklearn import cross_validation, datasets, metrics, neighbors 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['colors', 'clf']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=1)

# %%
classification_problem = datasets.make_classification(n_samples=500, n_features =2, n_informative = 2, 
                                                      n_classes = 4, n_redundant=0, 
                                                      n_clusters_per_class=1, random_state=3)

# %%
classification_problem
# Out:
# (array([[  1.38685399e+00,  -1.23802063e+00],
#         [ -8.18604569e-01,   9.11991776e-01],
#         [  1.06438883e+00,   1.16659789e+00],
#         [ -5.56886083e-01,  -1.53450211e+00],
#         [  3.95829885e-01,  -5.33282458e-01],
#         [ -9.21773731e-01,  -9.55597024e-01],
#         [ -1.14026189e+00,   1.07266720e+00],
#         [ -1.11810761e+00,  -6.62649671e-01],
#         [ -6.92558789e-01,   6.27599936e-01],
#         [ -1.75483235e+00,   8.96966400e-01],
#         [ -8.11808750e-01,   3.04525190e+00],
#         [  4.21007380e-01,  -2.98539117e-01],
#         [  1.20870201e+00,  -1.80656849e+00],
#         [  1.66585029e+00,  -1.60924155e+00],
#         [ -2.83353198e-01,  -3.00197958e-01],
#         [ -1.00795866e+00,  -2.27382299e-01],
#         [  6.06249695e-01,  -3.97629086e-01],
#         [  2.46122721e+00,  -5.44434490e-01],
#         [  2.00789074e+00,  -1.94435937e+00],
#         [  1.55203219e+00,  -5.83613182e-02],
#         [ -1.00063021e+00,  -1.89342084e+00],
#         [  1.83058513e+00,  -1.42274373e+00],
#         [ -1.05593401e+00,  -1.25823359e+00],
#         [ -9.01097438e-01,  -1.42096836e+00],
#         [  4.44740670e-01,  -5.26119930e-01],
#         [  1.67946166e+00,  -1.65507513e+00],
#         [ -1.46299891e+00,   1.11658149e+00],
#         [  2.45330710e+00,  -3.25233427e-01],
#         [ -1.47271881e+00,  -1.19309024e+00],
#         [ -1.64826470e+00,   1.08260336e+00],
#         [  2.15831009e+00,  -1.01291750e-01],
#         [  1.82057937e+00,  -1.65005157e+00],
#         [  4.79375936e-01,  -9.59652630e-01],
#         [  2.26408497e+00,  -1.99345066e-01],
#         [ -1.30618790e+00,  -3.95024442e-01],
#         [ -6.33198486e-01,   9.51573022e-01],
#         [ -7.72874224e-01,   1.14850278e+00],
#         [ -1.97399762e+00,   1.05345876e+00],
#         [ -1.03699222e+00,  -1.65927923e+00],
#         [  1.07069749e+00,   8.28412653e-01],
#         [  4.77265401e-01,  -9.43180681e-01],
#         [  8.32490046e-02,   2.05218659e+00],
#         [  2.29585046e-02,   9.21004335e-01],
#         [ -1.18353969e+00,   4.18353130e-01],
#         [ -1.06317837e+00,  -2.94795636e+00],
#         [  1.32565589e+00,  -1.75733001e+00],
#         [  3.83585784e-01,   8.52084616e-01],
#         [ -1.10802228e+00,  -1.51019908e+00],
#         [ -9.80349807e-01,  -2.10299239e-01],
#         [ -1.46722939e+00,   1.11672149e+00],
#         [  1.53598295e+00,   5.24714516e-01],
#         [ -9.91913723e-01,  -1.41465855e+00],
#         [  1.41242584e+00,   7.27831968e-01],
#         [ -1.39503360e-01,   7.89471112e-01],
#         [ -1.07373624e+00,  -3.92115951e-01],
#         [ -6.93702054e-01,  -1.06130558e+00],
#         [ -1.60170782e+00,   1.03598281e+00],
#         [ -1.19640159e-01,   8.95519176e-01],
#         [  3.83944188e-01,   1.52540308e+00],
#         [ -7.67726350e-01,   8.80911274e-01],
#         [  1.11759063e+00,   9.23896766e-01],
#         [ -5.27583219e-01,   2.73731776e+00],
#         [ -1.23305393e+00,   9.84495093e-01],
#         [  1.83765864e+00,  -3.40450840e-01],
#         [ -1.70011358e+00,   1.01711334e+00],
#         [ -8.82358817e-01,  -1.04744599e+00],
#         [  1.29918195e+00,   8.44476913e-01],
#         [ -1.22337981e+00,  -1.64694020e+00],
#         [  1.24492426e+00,  -1.58797943e+00],
#         [  1.09617250e-01,  -4.56994729e-01],
#         [  1.69175542e+00,  -1.80928660e+00],
#         [ -9.31522460e-01,  -5.86510262e-01],
#         [ -9.45266270e-01,  -7.10016069e-01],
#         [  1.30396718e+00,  -9.28584429e-01],
#         [ -8.26683359e-01,  -5.37795389e-01],
#         [  5.59922254e-01,  -7.29369658e-01],
#         [ -4.11177483e-01,   9.07698780e-01],
#         [ -2.86517959e-01,   3.92906231e-01],
#         [ -8.29697787e-02,  -3.16008502e-01],
#         [ -7.34078272e-01,  -3.39925125e-01],
#         [ -1.00098048e+00,  -1.08314292e-01],
#         [ -1.41792328e+00,  -1.26101023e+00],
#         [ -1.04968019e+00,  -8.42010674e-01],
#         [ -6.84386743e-01,  -1.51145327e+00],
#         [  5.50270574e-01,   1.63581240e+00],
#         [  4.77811843e-01,  -4.56242129e-01],
#         [ -1.26370869e+00,   6.07431697e-01],
#         [ -1.03594528e+00,  -1.23628424e+00],
#         [  1.94348413e+00,  -1.85381719e+00],
#         [ -6.11280821e-01,   7.98798699e-01],
#         [ -3.03415035e-02,   2.16382403e+00],
#         [ -9.53500605e-01,  -1.65645972e-01],
#         [ -9.10036116e-01,  -1.02221632e+00],
#         [ -1.40778484e+00,   1.14458451e+00],
#         [  1.13626791e+00,   9.97109603e-01],
#         [ -1.09851216e+00,  -2.38775509e-01],
#         [  1.31478721e+00,   7.11649964e-01],
#         [ -6.75747927e-01,  -1.22347066e+00],
#         [  7.78189473e-02,  -4.74569772e-01],
#         [ -9.49885822e-01,  -1.82101890e-01],
#         [ -9.21338178e-01,   8.72508481e-01],
#         [ -1.14889666e+00,   9.81836655e-01],
#         [ -5.05059989e-01,   8.10210347e-01],
#         [ -8.73879246e-01,  -1.45552805e+00],
#         [ -1.00946176e+00,  -1.52547744e+00],
#         [ -8.95367325e-01,   1.00995782e+00],
#         [  1.79886678e+00,  -1.65200744e+00],
#         [ -1.36943557e+00,   1.11589188e+00],
#         [ -9.17602255e-01,  -7.10630413e-01],
#         [ -1.30146115e+00,  -2.10655337e+00],
#         [  6.24961875e-01,  -6.15161126e-01],
#         [ -5.68594313e-01,   1.01992990e+00],
#         [ -4.06437271e-01,   2.49251240e+00],
#         [  2.67326560e+00,  -2.54566422e+00],
#         [  6.85900530e-01,   1.43015205e+00],
#         [ -1.07078469e+00,   8.27160855e-01],
#         [  2.32552371e+00,  -1.92551679e+00],
#         [ -9.55276188e-01,   7.64963989e-01],
#         [  3.80115540e-01,   1.76025588e+00],
#         [  3.07187156e+00,  -1.06153059e+00],
#         [ -8.67071535e-01,   2.93245031e+00],
#         [ -9.55518816e-01,  -5.43274080e-01],
#         [  1.47347785e-01,   2.23932997e+00],
#         [  1.26998722e+00,   3.78874412e-01],
#         [  5.77342221e-01,   1.25731143e+00],
#         [  6.90392656e-01,   1.57093446e+00],
#         [ -9.75451809e-01,  -1.37094959e+00],
#         [ -1.09255411e+00,  -1.02320400e+00],
#         [ -1.16731273e+00,   1.04615520e+00],
#         [ -1.05077358e+00,   3.11255974e+00],
#         [  2.81035458e+00,  -1.04493382e+00],
#         [ -7.44989090e-01,   8.73693816e-01],
#         [ -1.48029196e+00,   1.09299920e+00],
#         [ -6.42947415e-01,   1.01787100e+00]]),
#  array([1, 1, 3, 0, 1, 0, 2, 0, 1, 2, 3, 1, 1, 1, 1, 0, 1, 3, 1, 3, 0, 1, 0,
#         0, 1, 1, 2, 3, 0, 2, 3, 1, 1, 3, 0, 2, 2, 2, 0, 3, 1, 3, 2, 0, 0, 1,
#         3, 0, 0, 2, 3, 0, 3, 2, 2, 2, 2, 3, 2, 0, 0, 2, 3, 3, 0, 0, 2, 2, 2,
#         2, 0, 2, 2, 3, 0, 0, 3, 1, 2, 0, 2, 3, 1, 1, 0, 2, 2, 3, 3, 0, 2, 3,
#         3, 2, 0, 1, 2, 0, 2, 3, 3, 0, 3, 2, 1, 2, 1, 0, 2, 3, 1, 2, 3, 2, 0,
#         0, 2, 0, 2, 1, 2, 2, 3, 2, 2, 0, 2, 3, 3, 1, 0, 1, 1, 1, 0, 1, 0, 2,
#         3, 3, 0, 1, 0, 3, 0, 0, 0, 2, 3, 2, 1, 0, 3, 1, 0, 0, 2, 2, 2, 1, 0,
#         3, 0, 0, 0, 2, 1, 1, 1, 0, 3, 0, 1, 1, 2, 1, 2, 0, 0, 3, 1, 0, 3, 3,
#         0, 1, 3, 3, 3, 1, 3, 1, 0, 3, 1, 1, 1, 1, 0, 3, 1, 1, 1, 0, 2, 3, 3,
#         3, 3, 2, 2, 3, 3, 3, 1, 1, 1, 3, 0, 2, 3, 2, 2, 2, 1, 2, 0, 1, 1, 1,
#         2, 3, 2, 2, 3, 3, 3, 3, 3, 0, 3, 3, 0, 2, 2, 1, 1, 1, 1, 2, 3, 3, 0,
#         2, 1, 0, 2, 0, 1, 2, 0, 3, 1, 1, 3, 1, 2, 2, 2, 3, 1, 1, 1, 0, 0, 2,
#         0, 1, 1, 0, 0, 2, 1, 3, 2, 3, 1, 3, 2, 2, 1, 1, 0, 0, 1, 2, 3, 1, 2,
#         3, 0, 3, 0, 2, 1, 3, 0, 1, 1, 2, 0, 1, 0, 1, 1, 2, 1, 2, 1, 1, 3, 0,
#         0, 2, 3, 3, 3, 1, 2, 0, 3, 1, 0, 1, 3, 3, 0, 3, 3, 2, 1, 0, 3, 3, 1,
#         3, 1, 3, 3, 0, 1, 2, 3, 0, 1, 0, 3, 2, 3, 3, 0, 0, 3, 2, 0, 1, 2, 3,
#         2, 3, 1, 0, 2, 2, 2, 3, 2, 1, 2, 0, 2, 0, 0, 1, 2, 2, 2, 1, 0, 2, 3,
#         1, 1, 3, 2, 3, 1, 1, 3, 3, 2, 2, 1, 2, 1, 3, 1, 0, 0, 2, 3, 3, 0, 3,
#         0, 0, 1, 3, 3, 1, 0, 0, 2, 2, 3, 2, 3, 3, 2, 3, 2, 0, 3, 0, 1, 1, 1,
#         0, 0, 1, 0, 1, 2, 1, 1, 0, 0, 0, 0, 0, 3, 1, 1, 0, 1, 2, 3, 0, 0, 2,
#         3, 0, 3, 0, 1, 0, 2, 2, 2, 0, 0, 2, 1, 2, 0, 0, 1, 2, 3, 1, 3, 2, 1,
#         1, 3, 3, 3, 0, 3, 3, 3, 3, 0, 0, 2, 3, 3, 2, 2, 2]))

# %%
colors = ListedColormap(['b', 'g', 'r','y'])
light_colors = ListedColormap(['lightcoral', 'lightblue', 'lightyellow', 'lightgreen'])

# %%
pylab.figure(figsize=(10,10))
pylab.scatter(map(lambda x: x[0], classification_problem[0]), map(lambda x: x[1], classification_problem[0]), c=classification_problem[1], cmap=colors, s=20)

# %%
train_data, test_data, train_labels, test_labels = cross_validation.train_test_split(classification_problem[0], 
                                                                                     classification_problem[1], 
                                                                                     test_size = 0.3,
                                                                                     random_state = 1)

# %%
clf = neighbors.KNeighborsClassifier()
clf.fit(train_data, train_labels)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
def get_meshgrid(data, step=.05, border=.5,):
    x_min, x_max = data[:, 0].min() - border, data[:, 0].max() + border
    y_min, y_max = data[:, 1].min() - border, data[:, 1].max() + border
    return np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# %% [markdown]
# ## n = 1

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=1)
#fit model
estimator.fit(train_data, train_labels)
    
#set figure size
pyplot.figure(figsize = (10, 10))
    
#plot decision surface on the train data 
pyplot.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(estimator.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, s = 15, cmap = colors)
pyplot.title('Train data, accuracy={:.2f}'.format(metrics.accuracy_score(train_labels, estimator.predict(train_data))))

#plot decision surface on the test data
pyplot.subplot(1,2,2)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, s = 25, cmap = colors)
pyplot.title('Test data, accuracy={:.2f}'.format(metrics.accuracy_score(test_labels, estimator.predict(test_data))))

# %% [markdown]
# ## n = 2

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=2)
#fit model
estimator.fit(train_data, train_labels)
    
#set figure size
pyplot.figure(figsize = (10, 10))
    
#plot decision surface on the train data 
pyplot.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(estimator.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, s = 15, cmap = colors)
pyplot.title('Train data, accuracy={:.2f}'.format(metrics.accuracy_score(train_labels, estimator.predict(train_data))))

#plot decision surface on the test data
pyplot.subplot(1,2,2)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, s = 25, cmap = colors)
pyplot.title('Test data, accuracy={:.2f}'.format(metrics.accuracy_score(test_labels, estimator.predict(test_data))))

# %% [markdown]
# ## n = 5

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=5)
#fit model
estimator.fit(train_data, train_labels)
    
#set figure size
pyplot.figure(figsize = (10, 10))
    
#plot decision surface on the train data 
pyplot.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(estimator.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, s = 15, cmap = colors)
pyplot.title('Train data, accuracy={:.2f}'.format(metrics.accuracy_score(train_labels, estimator.predict(train_data))))

#plot decision surface on the test data
pyplot.subplot(1,2,2)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, s = 25, cmap = colors)
pyplot.title('Test data, accuracy={:.2f}'.format(metrics.accuracy_score(test_labels, estimator.predict(test_data))))

# %% [markdown]
# ## n = 10

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=10)
#fit model
estimator.fit(train_data, train_labels)
    
#set figure size
pyplot.figure(figsize = (10, 10))
    
#plot decision surface on the train data 
pyplot.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(estimator.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, s = 15, cmap = colors)
pyplot.title('Train data, accuracy={:.2f}'.format(metrics.accuracy_score(train_labels, estimator.predict(train_data))))

#plot decision surface on the test data
pyplot.subplot(1,2,2)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, s = 25, cmap = colors)
pyplot.title('Test data, accuracy={:.2f}'.format(metrics.accuracy_score(test_labels, estimator.predict(test_data))))

# %% [markdown]
# ## n = 50

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=50)
#fit model
estimator.fit(train_data, train_labels)
    
#set figure size
pyplot.figure(figsize = (10, 10))
    
#plot decision surface on the train data 
pyplot.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(estimator.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, s = 15, cmap = colors)
pyplot.title('Train data, accuracy={:.2f}'.format(metrics.accuracy_score(train_labels, estimator.predict(train_data))))

#plot decision surface on the test data
pyplot.subplot(1,2,2)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, s = 25, cmap = colors)
pyplot.title('Test data, accuracy={:.2f}'.format(metrics.accuracy_score(test_labels, estimator.predict(test_data))))

# %% [markdown]
# ## n = 100

# %%
estimator = neighbors.KNeighborsClassifier(n_neighbors=100)
#fit model
estimator.fit(train_data, train_labels)
    
#set figure size
pyplot.figure(figsize = (10, 10))
    
#plot decision surface on the train data 
pyplot.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(estimator.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, s = 15, cmap = colors)
pyplot.title('Train data, accuracy={:.2f}'.format(metrics.accuracy_score(train_labels, estimator.predict(train_data))))

#plot decision surface on the test data
pyplot.subplot(1,2,2)
pyplot.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
pyplot.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, s = 25, cmap = colors)
pyplot.title('Test data, accuracy={:.2f}'.format(metrics.accuracy_score(test_labels, estimator.predict(test_data))))

# %%
kf = cross_validation.KFold(len(classification_problem[0]), 5, shuffle=True)

# %%
for train_ind, test_ind in kf:
    estimator = neighbors.KNeighborsClassifier(n_neighbors=1)
    estimator.fit(classification_problem[0][train_ind], classification_problem[1][train_ind])

# %%
estimator
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')
